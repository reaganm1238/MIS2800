# %% [markdown]
# <a href="https://colab.research.google.com/github/reaganm1238/MIS2800/blob/main/HW3_McHenry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# /bin/bash: line 1: pip install --upgrade pandas ipython-sql prettytable==3.10.1: command not found

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# /bin/bash: line 1: pip install ipython-sql: command not found
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# Instructions: Fix the code to select all the columns from the Marketing Brands
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-808876474.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT * FROM Marketing_Brands;\n\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-120> in execute(self, line, cell, local_ns)
#
# ...

# %%
#Block 4
# Instructions: Fix the code to display only the brand names and brand types that have a budget over 7,000,000
# %%sql
SELECT brand_name , brand_type  FROM Marketing_Brands; WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# (sqlite3.OperationalError) near "WHERE": syntax error
# [SQL: WHERE brand_budget > 7000000]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Instructions: Fix the code to find the brand types that are Religious
# %%sql
 SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-921566730.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', " SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious'\n")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
# %%sql
# -- Instructions: Fix the code to display the brand names that have a budget under 1000000
# SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3942542630.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', '--\xa0Instructions:\xa0Fix\xa0the\xa0code\xa0to\xa0display\xa0the\xa0brand\xa0names\xa0that\xa0have\xa0a\xa0budget under 1000000\nSELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# ...

# %%
# Instructins: Fix the code so that this will run SQLite3 in Colab without having to wrap in python
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3565976819.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
# %%sql
# --Instructions: Find the brands where the brand type is Snacks or Beverages
# SELECT * FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-362817393.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "--Instructions:\xa0Find\xa0the\xa0brands\xa0where\xa0the\xa0brand\xa0type\xa0is\xa0Snacks\xa0or\xa0Beverages\nSELECT * FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'\n")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# ...

# %%
# %%sql
# -- Instructions: Sort the table by brand budget in DESC order. Display only the brand_name and brand_budget
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2310472436.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', '--\xa0Instructions:\xa0Sort\xa0the\xa0table\xa0by\xa0brand\xa0budget\xa0in\xa0DESC\xa0order.\xa0Display\xa0only the brand_name and brand_budget\nSELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
# ...

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a table showing all the columns in ascending order by budget
# %%sql
SELECT brand_id, brand_name, brand_type, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3108919633.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT brand_id, brand_name, brand_type, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
# ...
