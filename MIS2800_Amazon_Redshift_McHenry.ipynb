# %% [markdown]
# <a href="https://colab.research.google.com/github/reaganm1238/MIS2800/blob/main/MIS2800_Amazon_Redshift_McHenry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1:
# The integration of redshift data allowed for Lyft to innovate because of the large scale data storage and analytical tools. redshift also allowed Lyft to predict things such as rider patterns and demand that helped with pricing as well as paving the way for the Lyft Line feature.
#
#
# Question 2:
# OLTP and OLAP have different purposes when it comes to data processing. OLTP is a better fit for the app since its main purpose is bookings, payments and matching riders with drivers. On the other hand OLAP is more of a predictive tool, being used for forecasting and price analysis, and optimization.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: Columnar storage is better when it comes to tables because it is very storage efficient, with each data block holding 3x the amount of data as a normalized table. You can also save query and memory space using columnar storage, since data retrieval only pulls the column you need rather than the entire row.
#
# Question 2: This architechture greatly speeds up BI report generation through parallel processing. This is because the leader node receives the query and breaks the nodes up so they can be processed simultaneously, which cuts down on time tenfold.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: Knowing that our systems are capable of analyzing past data and recognizing patterns, I would likely skip the data colection questions altogether when talking to my team and instead ask them for suggestions moving forward, or what emerging patterns they have noticed and what we can do about them.
#
# Question 2: ETL or "Extract, Transform, Load" is the process where the best, most representative data is pulled from the data set and sent elsewhere to be analyzed. This is an important step since data with missing values or inconsistencies may lead analysts to draw incorrect or ill informed conclusions about the data. For this reason, it is extremely important that our data is extracted properly.
